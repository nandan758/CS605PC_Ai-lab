# %% [markdown]
# <a href="https://colab.research.google.com/github/nandan758/CS605PC_Ai-lab/blob/main/monkey_and_banana_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hello(state):
        print("Initial State is: " ,state)
        state["monkey"] = state["box"]
        state["box"] = state["banana"]
        state["banana"] = state["box"]
        print("Goal State is:" ,state)

one = input("enter monkey position")
two = input("enter box position")
three = input("enter banana position")
state = {'monkey':one, 'box':two, 'banana':three}
hello(state)
# Out:
# enter monkey positionone
# enter box positiontwo
# enter banana positionthree
# Initial State is:  {'monkey': 'one', 'box': 'two', 'banana': 'three'}
# Goal State is: {'monkey': 'two', 'box': 'three', 'banana': 'three'}
